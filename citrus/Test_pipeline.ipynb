# %%
# !pip install livelossplot==0.5.2

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/AgroLabs # The folder containing all the required files and data

# %%
# !pip install --upgrade wandb

# %%
import wandb

# %%
wandb.login()

# %%
# !python train.py --tf --tlf
