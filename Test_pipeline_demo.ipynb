# %% [markdown]
# <a href="https://colab.research.google.com/github/Future-AI-Laboratory/vision-api/blob/review_sayan/Test_pipeline_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install Dependencies**

# %%
# !pip install livelossplot

# %%
# !pip install --upgrade wandb

# %% [markdown]
# # **Run The Train Pipeline**

# %% [markdown]
# >* **--df = Enables the Download Flag to True to include data download, unzip in the pipeline, default False**
# >* **--da = Disables the Data Analysis in the pipeline to False, by deafult True(optional)**
# >* **--tf = Enables the Training Flag to True to include Training in the pipeline, default False**
# >* **--tlf = Enables the TFlite model conversion step to True in the pipeline, default False**

# %%
# !python train.py --df --tf --tlf
# Out:
# 2021-05-14 23:54:13.019599: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Reproducibility steps done!
# 2021-05-14 23:54:15.396709: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-05-14 23:54:15.398085: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-05-14 23:54:15.471946: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-14 23:54:15.472958: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %% [markdown]
# # **Inference Pipeline Run**

# %%
import inference

# %%
inference.inference('demo_images', None)
# Out:
# List of images
# ['Potato_early_blight.JPG', 'Potato_late_blight.JPG', 'Potato_healthy.JPG']
